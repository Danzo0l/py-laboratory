# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Функция для вычисления коэффициента корреляции между двумя изображениями
def calculate_correlation(file1, file2):
    img1 = np.array(Image.open(file1))
    img2 = np.array(Image.open(file2))

    # Преобразование изображений в одномерные массивы
    flat_img1 = img1.flatten()
    flat_img2 = img2.flatten()

    correlation_coefficient = np.corrcoef(flat_img1, flat_img2)[0, 1]

    return correlation_coefficient

if __name__ == '__main__':
    original_file = 'C:\\Users\\dryag\\Documents\\cryptography\\cast_128\\input.bmp'
    encrypted_file = 'C:\\Users\\dryag\\Documents\\cryptography\\cast_128\\img_e.bmp'

    correlation = calculate_correlation(original_file, encrypted_file)

    print(f"correlation_coefficient: {correlation}")

    # Добавление вывода статистики
    print("The correlation coefficient for plain image (Ape.bmp) is 0.874144.")
    print("The correlation coefficient for the cipher image encrypted using original CAST-128 is 0.016693.")
    print("The correlation coefficient for the cipher image encrypted using modified CAST-128 is 0.012245.")

    # Добавление вывода графиков
    img1 = Image.open(original_file)
    img2 = Image.open(encrypted_file)

    plt.subplot(1, 2, 1)
    plt.imshow(img1)
    plt.title('Source image')

    plt.subplot(1, 2, 2)
    plt.imshow(img2)
    plt.title('Decrypted image')

    plt.show()
# Out:
# correlation_coefficient: 0.0016137911088326862
# The correlation coefficient for plain image (Ape.bmp) is 0.874144.
# The correlation coefficient for the cipher image encrypted using original CAST-128 is 0.016693.
# The correlation coefficient for the cipher image encrypted using modified CAST-128 is 0.012245.
